# %%
import qubx
from qubx import lookup
from collections import defaultdict

# %load_ext autoreload
# %autoreload 2
from tubx.data.misc import  BinanceMarketsHelper

# %%
mh = BinanceMarketsHelper()

# %%
mh = BinanceMarketsHelper()
sect = mh.listings_by_sector('USDT',as_frame=False)

# %%
sect['ai']

# %%
for s, si in sect.items():
    si

# %%
for i in si.itertuples():
    print(i)
# Out:
# Pandas(Index=0, Symbol='MOVEUSDT', MarketCap=1907.325)
# Pandas(Index=1, Symbol='PENGUUSDT', MarketCap=1616.511984)
# Pandas(Index=2, Symbol='VANAUSDT', MarketCap=517.023624)
# Pandas(Index=3, Symbol='USUALUSDT', MarketCap=511.6780943236)
# Pandas(Index=4, Symbol='MEUSDT', MarketCap=386.788908495)
# Pandas(Index=5, Symbol='VELODROMEUSDT', MarketCap=336.592)
# Pandas(Index=6, Symbol='1000CATUSDT', MarketCap=328.05)
# Pandas(Index=7, Symbol='ACXUSDT', MarketCap=185.0515903956)
# Pandas(Index=8, Symbol='ORCAUSDT', MarketCap=184.545303192)
# Pandas(Index=9, Symbol='THEUSDT', MarketCap=101.87160696919999)

# %%
mh.ls_sectors()

# %%
import numpy as np
import pandas as pd

# %%
pd.date_range("2021-01-01", periods=100, freq="1d").values
# Out:
# array(['2021-01-01T00:00:00.000000000', '2021-01-02T00:00:00.000000000',
#        '2021-01-03T00:00:00.000000000', '2021-01-04T00:00:00.000000000',
#        '2021-01-05T00:00:00.000000000', '2021-01-06T00:00:00.000000000',
#        '2021-01-07T00:00:00.000000000', '2021-01-08T00:00:00.000000000',
#        '2021-01-09T00:00:00.000000000', '2021-01-10T00:00:00.000000000',
#        '2021-01-11T00:00:00.000000000', '2021-01-12T00:00:00.000000000',
#        '2021-01-13T00:00:00.000000000', '2021-01-14T00:00:00.000000000',
#        '2021-01-15T00:00:00.000000000', '2021-01-16T00:00:00.000000000',
#        '2021-01-17T00:00:00.000000000', '2021-01-18T00:00:00.000000000',
#        '2021-01-19T00:00:00.000000000', '2021-01-20T00:00:00.000000000',
#        '2021-01-21T00:00:00.000000000', '2021-01-22T00:00:00.000000000',
#        '2021-01-23T00:00:00.000000000', '2021-01-24T00:00:00.000000000',
#        '2021-01-25T00:00:00.000000000', '2021-01-26T00:00:00.000000000',
# ...

# %%
for i in lookup.find_instruments("BINANCE.UM"):
    abd[i.symbol[:2]].append(i)

# %%
from qubx.utils.marketdata.binance import load_binance_markets_info

# %%
data = load_binance_markets_info()

# %%
data
# Out:
# (              Symbol     MarketCap   Coin Quoted        Name  \
#  BTCARS        BTCARS  2.268687e+09    BTC    ARS     Bitcoin
#  USDTCOP      USDTCOP  6.028518e+08   USDT    COP    TetherUS
#  ETHARS        ETHARS  4.767460e+08    ETH    ARS    Ethereum
#  BTCJPY        BTCJPY  2.952042e+08    BTC    JPY     Bitcoin
#  USDTARS      USDTARS  1.681691e+08   USDT    ARS    TetherUS
#  ...              ...           ...    ...    ...         ...
#  BTTCTRY      BTTCTRY  0.000000e+00   BTTC    TRY  BitTorrent
#  STRAXUSDT  STRAXUSDT  0.000000e+00  STRAX   USDT     Stratis
#  EUREURI      EUREURI  0.000000e+00    EUR   EURI        Euro
#  BTTCUSDT    BTTCUSDT  0.000000e+00   BTTC   USDT  BitTorrent
#  STRAXBTC    STRAXBTC  0.000000e+00  STRAX    BTC     Stratis
#
#                                          Tags
#  BTCARS          [pow, mining-zone, Payments]
#  USDTCOP                         [stablecoin]
#  ETHARS     [Layer1_Layer2, pos, mining-zone]
# ...

# %%
abd
